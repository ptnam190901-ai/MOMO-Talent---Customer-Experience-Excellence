# %%
import pandas as pd

# %%
ticket = pd.read_excel('/Users/hahieuthien/Desktop/Pham Trung Nam/[CX DA]_Case Study Round_Questions_Talent.xlsx','Data_ticket') # Import the ticket sheet from Excel file
sla = pd.read_excel('/Users/hahieuthien/Desktop/Pham Trung Nam/[CX DA]_Case Study Round_Questions_Talent.xlsx','Data_SLA') # Import the SLA sheet from Excel file

# %%
ticket.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5187 entries, 0 to 5186
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ticket_id        5187 non-null   object
#  1   Agent_tiep_nhan  5187 non-null   str
#  2   Level            5187 non-null   str
#  3   Created_date     5187 non-null   datetime64[us]
# dtypes: datetime64[us](1), object(1), str(2)
# memory usage: 162.2+ KB

# %%
sla.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5187 entries, 0 to 5186
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ticket_id     5187 non-null   object
#  1   Chuyen_time   5187 non-null   datetime64[us]
#  2   Phanhoi_time  5187 non-null   datetime64[us]
#  3   SLA_Camket    5187 non-null   int64
# dtypes: datetime64[us](2), int64(1), object(1)
# memory usage: 162.2+ KB

# %% [markdown]
# Through two initial investigations through two datasets, it can be seen that neither of them have missing values, and they have the same rows entries. The ticket_id is the same for the both data, so we can join them.

# %%
ticket.iloc[3930]
# Out:
# Ticket_id                260312.000022
# Agent_tiep_nhan             ngan.pham1
# Level              Nạp tiền điện thoại
# Created_date       2026-03-12 00:00:00
# Name: 3930, dtype: object

# %%
ticket.to_excel("/Users/hahieuthien/Desktop/Pham Trung Nam/data_ticket.xlsx", index=False)
sla.to_excel("/Users/hahieuthien/Desktop/Pham Trung Nam/data_sla.xlsx", index=False)
